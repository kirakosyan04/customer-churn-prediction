# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()

# %%
model.load_model("models/xgboost_model.json")

# %%
booster = model.get_booster()
print(booster)
# Out:
# <xgboost.core.Booster object at 0x110f1cc20>

# %%
model.get_booster()

# %%
import pandas as pd

df = pd.read_csv("data/customer_churn.csv")

print(df.shape)
# Out:
# (20, 4)
